# %%
from googleapiclient.discovery import build

api_key = 'AIzaSyCT9OUWE4_4URbEOxiBGR2Re6PpWTBSCD8'

def video_comments(video_id):
	# empty list for storing reply
	replies = []

	# creating youtube resource object
	youtube = build('youtube', 'v3',
					developerKey=api_key)

	# retrieve youtube video results
	video_response=youtube.commentThreads().list(
	part='snippet,replies',
	videoId=video_id
	).execute()

	# iterate video response
	while video_response:
	
		# extracting required info
		# from each result object
		for item in video_response['items']:
		
			# Extracting comments
			comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
			
			# counting number of reply of comment
			# replycount = item['snippet']['totalReplyCount']

			# if reply is there
# 			if replycount>0:
			
# 				# iterate through all reply
# 				for reply in item['replies']['comments']:
				
# 					# Extract reply
# 					reply = reply['snippet']['textDisplay']
					
# 					# Store reply is list
# 					replies.append(reply)

			# print comment with list of reply
# 			print(comment, replies, end = '\n\n')

			# empty reply list
			replies = []

		# Again repeat
		if 'nextPageToken' in video_response:
			video_response = youtube.commentThreads().list(
					part = 'snippet,replies',
					videoId = video_id
				).execute()
		else:
			break

# %%
# Enter video id
#https://www.youtube.com/watch?v=Beld090NIoo
video_id = "Beld090NIoo"
replies = []

# creating youtube resource object
youtube = build('youtube', 'v3',
                developerKey=api_key)

# %%
# retrieve youtube video results
video_response=youtube.commentThreads().list(
part='snippet,replies',
videoId=video_id
).execute()

# %%
video_response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'svgkKMrg_B79n4MlCMtWgSrqhjY',
#  'nextPageToken': 'QURTSl9pMnFjZ3VLcHhOeC0tbkJ1WlpnODU5bGVuVlFsbENKUGJmUzdKOUFmS3o3cUl4Z0Jqa3p2X2hXVzZzd0RfSEZpekE1aXZmUlBlQQ==',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': '-90KH3GfQVzvE9XeAYzwd9IisgU',
#    'id': 'UgxmV9Ouv-DGcD93Du14AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Yw_DAHXSducdMsuFsYQhQ-cPODw',
#      'id': 'UgxmV9Ouv-DGcD93Du14AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'thats really great !!!!',
#       'textOriginal': 'thats really great !!!!',
#       'authorDisplayName': 'aubelop',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AOPolaSSlqV5tFF_6ULpQ50zhowXiNOxGVrnagmIWQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC4HXejh0pNZa0eAzKnqz9_Q',
#       'authorChannelId': {'value': 'UC4HXejh0pNZa0eAzKnqz9_Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-07T14:11:14Z',
#       'updatedAt': '2023-07-07T14:11:14Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'djaq7Z5BVSkXlosRHguv_5qSzN8',
#    'id': 'Ugw1lB4Ny1UbJVnbzTN4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Ow0wktGW9F-U8T0GfPx3zB38q5M',
#      'id': 'Ugw1lB4Ny1UbJVnbzTN4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'Great mix thank you',
#       'textOriginal': 'Great mix thank you',
#       'authorDisplayName': 'Scott Cattell',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AOPolaRBQMko7DnyYD_96O9UEP-OHS_58MuuvAJz5Yubhg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCubi_SxqF7IebXkOl_mRCSA',
#       'authorChannelId': {'value': 'UCubi_SxqF7IebXkOl_mRCSA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-07T11:32:43Z',
#       'updatedAt': '2023-07-07T11:32:43Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '3v2AESInRyPfSxrgH88FjVvpOvM',
#    'id': 'UgyCeXrMJjWhoq-R89t4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '3QBq9fZzmpEjuj0cqlvwg21Vclc',
#      'id': 'UgyCeXrMJjWhoq-R89t4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'Fire 🔥 in da house!! Dem a murdera!!!!',
#       'textOriginal': 'Fire 🔥 in da house!! Dem a murdera!!!!',
#       'authorDisplayName': 'William Jones',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOaw14yD6qgBPEot2Gwe7O7Zzlgop404HGzHQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCfzeT6vcYLXzGsDxwe3lXLw',
#       'authorChannelId': {'value': 'UCfzeT6vcYLXzGsDxwe3lXLw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-07T00:06:16Z',
#       'updatedAt': '2023-07-07T00:06:16Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Z09IJDKjuygGlk3YRxWAQLbaZ0o',
#    'id': 'Ugy0y0BDMVVyXHjmVeN4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-NAom5ftEmXYDJzxCtoVO2og1bA',
#      'id': 'Ugy0y0BDMVVyXHjmVeN4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'Esto es espectacular! muy muy bueno',
#       'textOriginal': 'Esto es espectacular! muy muy bueno',
#       'authorDisplayName': 'Federico Medun',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqNZdwKnCCWpEbpgovUYXZwOnxTqRd1FFhV7SoiRUw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCE9XngyCHQYtqMHxJmZR8xA',
#       'authorChannelId': {'value': 'UCE9XngyCHQYtqMHxJmZR8xA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-06T22:55:51Z',
#       'updatedAt': '2023-07-06T22:55:51Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'A7MmTTTRAoeCvzOsD9om_F-iG_U',
#    'id': 'Ugwh4BryBndLpSzdHeZ4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OuK5yRaQR7YabVWEYV00NkGRV98',
#      'id': 'Ugwh4BryBndLpSzdHeZ4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'почему только сейчас мне попались ваши великолепные сэты.....спасибо)',
#       'textOriginal': 'почему только сейчас мне попались ваши великолепные сэты.....спасибо)',
#       'authorDisplayName': 'Call The Priest',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/hDLo6xAGpZdd350H-yUBo33b8pT0l9fIRgIfTmU6FGXnGS4gyEy1wUXQT0Bq6Vbghj4EMjrF2A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCEsb-OGNySARxio0gfTW6OA',
#       'authorChannelId': {'value': 'UCEsb-OGNySARxio0gfTW6OA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-06T06:12:37Z',
#       'updatedAt': '2023-07-06T06:12:37Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LWa10MgaViJg_SHqJZF2X1w3pP0',
#    'id': 'Ugxe1dPRFZ3AmzP32g94AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '7bcqFHc_eYNoo_45nYVaEfjxUhw',
#      'id': 'Ugxe1dPRFZ3AmzP32g94AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'indian vibes',
#       'textOriginal': 'indian vibes',
#       'authorDisplayName': 'Zions6886',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AOPolaSWvfvvHdMup5Ta1Trq9x-nsTOeErnviEvCjw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCyG-frGaVt2CXf2axgc6uww',
#       'authorChannelId': {'value': 'UCyG-frGaVt2CXf2axgc6uww'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-05T08:55:01Z',
#       'updatedAt': '2023-07-05T08:55:01Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Ghxf7IvYA-Ru0JiMrc8iHJkVym0',
#    'id': 'UgxaS4SX7xLTO8uF5Nh4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2RoCU5XkL6u4bt7ksdqlQP3Xzfc',
#      'id': 'UgxaS4SX7xLTO8uF5Nh4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'Loving the plants and the set up',
#       'textOriginal': 'Loving the plants and the set up',
#       'authorDisplayName': 'Alex T',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqNzcE67Ht_skl9MeVeKtnA9275BSJ4J_I7AyEa1AA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCnTZmJ9wHB9fNh_gU6Da3uw',
#       'authorChannelId': {'value': 'UCnTZmJ9wHB9fNh_gU6Da3uw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-05T08:33:27Z',
#       'updatedAt': '2023-07-05T08:33:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xF8D7CV8-5EggFTXut2mlaYZ_LE',
#    'id': 'UgxVuB38_nGMwxIxjcB4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'YRjqn5UuUZ_cdSPBmjx6NDA1fJc',
#      'id': 'UgxVuB38_nGMwxIxjcB4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'good music and very bad dijing skills (shame)',
#       'textOriginal': 'good music and very bad dijing skills (shame)',
#       'authorDisplayName': 'Joan Sala Serra',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AOPolaRmEgbJE38zMiXUnkshqPOdJO2LGLz8DUMzTK5V=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCyrOy4Hz5doy-VFvMuRbw4Q',
#       'authorChannelId': {'value': 'UCyrOy4Hz5doy-VFvMuRbw4Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-05T04:19:02Z',
#       'updatedAt': '2023-07-05T04:19:02Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '9vEai0BKGe0CDgtOk4gXpiGuhHs',
#    'id': 'Ugzaa9HNlxij5viq14R4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'gFvi-FpqZNQQdZ0ee3zh2kelSyE',
#      'id': 'Ugzaa9HNlxij5viq14R4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'what an incredible set...thank you for introducing me to the dub specialist!!',
#       'textOriginal': 'what an incredible set...thank you for introducing me to the dub specialist!!',
#       'authorDisplayName': 'David Justice',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AOPolaS4TqfUYRKFgk2k36KCAI-Zu8ZjKxUuED8sBnc=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCJOrHZxhNZpUoaYAv7VxzLw',
#       'authorChannelId': {'value': 'UCJOrHZxhNZpUoaYAv7VxzLw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-04T22:27:59Z',
#       'updatedAt': '2023-07-04T22:34:08Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '21zJuvZs1nkvgiZYcSyeNmS_rw4',
#    'id': 'Ugy2E5ekfzZ8f75yrEl4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'QfcqOjgjbcMu8087Fk01sC--VYE',
#      'id': 'Ugy2E5ekfzZ8f75yrEl4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'Yeeeees ❤',
#       'textOriginal': 'Yeeeees ❤',
#       'authorDisplayName': 'NiciNice',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/CvtA0U_LuQwYmyOzfC170mCzd_4MpODNj1QkkJM0e5FhXUm-0uByPRzRX7HVJsh3y7X0_FUzgWM=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCd_cEFlXIGEI9SiN9yi_kYg',
#       'authorChannelId': {'value': 'UCd_cEFlXIGEI9SiN9yi_kYg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-04T20:44:27Z',
#       'updatedAt': '2023-07-04T20:44:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'PGRasmQouoRMgx5WE4IebbGMiT4',
#    'id': 'UgxRJ_2e-t7svePxTHF4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'EPYSr_w1xgG5agost10nlFc23Cw',
#      'id': 'UgxRJ_2e-t7svePxTHF4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': '🎉 super!',
#       'textOriginal': '🎉 super!',
#       'authorDisplayName': 'Evelin Ibarra',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqNE5opA-Aej0PKeRnFf7XEyh13gCgdnhhIKWM8se55ZmBBbblFbyU0ks_aIeIZH=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC5nsTRZxJObVuZlshf6yPfw',
#       'authorChannelId': {'value': 'UC5nsTRZxJObVuZlshf6yPfw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-04T19:19:04Z',
#       'updatedAt': '2023-07-04T19:19:04Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'mZFqJb8vXZ-jmQpiAzcglhLRZxs',
#    'id': 'UgzobKAFrZ0zIhR1eQx4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'MdmMa435bwlYb3jT7qp9o5HvgWg',
#      'id': 'UgzobKAFrZ0zIhR1eQx4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'Anyone have any recommendations of other dj’s or music similar to this? I am in love with this mix such  a good vibe! Thanks ahead of time appreciate you 🙃❤️🎶🍄',
#       'textOriginal': 'Anyone have any recommendations of other dj’s or music similar to this? I am in love with this mix such  a good vibe! Thanks ahead of time appreciate you 🙃❤️🎶🍄',
#       'authorDisplayName': 'Joshua Weaver',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AOPolaT8b4nKuHdp-BSmSaZk4P2R6oVu7wnnZI0u_KevxA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCbbt9s_Ib9Kg-mjr25aTKNw',
#       'authorChannelId': {'value': 'UCbbt9s_Ib9Kg-mjr25aTKNw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-04T18:36:37Z',
#       'updatedAt': '2023-07-04T18:36:37Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '2973GPRUXX2mruDzOjBeSNzAkJY',
#    'id': 'UgwXk1Lz-2mV3h7aMKF4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'u_SnAiBYe6AKiMcWdUff40O1wDs',
#      'id': 'UgwXk1Lz-2mV3h7aMKF4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'The last five minutes got me hypedfruitlooped! LOVED THIS SET MAAAN!',
#       'textOriginal': 'The last five minutes got me hypedfruitlooped! LOVED THIS SET MAAAN!',
#       'authorDisplayName': 'Emilio Maruri',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqOXqUL68kjm_CcWbX_c8wrqW9U0cYQ3C0AShA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCJOP__X-UOx4SUp-Ur6CfMg',
#       'authorChannelId': {'value': 'UCJOP__X-UOx4SUp-Ur6CfMg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-04T15:53:23Z',
#       'updatedAt': '2023-07-04T15:53:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'bh6nI_RWYr-dFh_ajzlF3EcZjTA',
#    'id': 'UgxIroig8tdk8dIJ4hZ4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'lvMxr05gXhqgUWxBP-CWZIk9Y30',
#      'id': 'UgxIroig8tdk8dIJ4hZ4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'This perked me up so much today at work!',
#       'textOriginal': 'This perked me up so much today at work!',
#       'authorDisplayName': 'Jessica Eleanor',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqNybvR9iHmg4n9Teo921UFcG4tj4Buvx6rTf1u7jQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC1LULKYDNS4pHK-f3-5iOsg',
#       'authorChannelId': {'value': 'UC1LULKYDNS4pHK-f3-5iOsg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-04T15:43:06Z',
#       'updatedAt': '2023-07-04T15:43:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 's4FDEykmeGAq7ueG0hNXNZhYu2U',
#    'id': 'UgyyAl7mzZDx445kWnF4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'uBJTplIFtf-UPQhNDBjfd5Nant0',
#      'id': 'UgyyAl7mzZDx445kWnF4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=Beld090NIoo&amp;t=28m30s">28:30</a> OMFG THIS TRACK',
#       'textOriginal': '28:30 OMFG THIS TRACK',
#       'authorDisplayName': 'GROOVE TECH SETS',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AOPolaQM04Yq1Rc0_fgQkXnTye589D2fu8uNdc1xaG7paA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC-rwVx-_yjFsTVqXL3mtvAA',
#       'authorChannelId': {'value': 'UC-rwVx-_yjFsTVqXL3mtvAA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-04T07:48:02Z',
#       'updatedAt': '2023-07-04T07:48:02Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '4TRJPzvG6uWvCTdxrVGzM-Aunt0',
#    'id': 'UgzFx_IUrmNbbdI_2Q54AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ex9h0icDz1kM0WWhfvNMUy5tqoE',
#      'id': 'UgzFx_IUrmNbbdI_2Q54AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'what&#39;s that rotary mixer? can&#39;t quite read the name without my glasses..',
#       'textOriginal': "what's that rotary mixer? can't quite read the name without my glasses..",
#       'authorDisplayName': 'Seppia',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AOPolaSPw7ICLO9po5Xq3AzQjCgMII2ipWWqZsY6nL9bDQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCI3xIr9orgnQaRAd9L9VrGw',
#       'authorChannelId': {'value': 'UCI3xIr9orgnQaRAd9L9VrGw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-04T07:47:57Z',
#       'updatedAt': '2023-07-04T07:47:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'i1Tke46P2e5p_tXy7BdZwJQFl4w',
#    'id': 'UgwF1i9asYhr1nPxFyZ4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'uOvxbHgZETtITmMLsfz9XinPdXA',
#      'id': 'UgwF1i9asYhr1nPxFyZ4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'Thank you. This was perfect for my night of relaxation.',
#       'textOriginal': 'Thank you. This was perfect for my night of relaxation.',
#       'authorDisplayName': 'Coffee House',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-wAwd2xP-sImHkzifwW3k4uW1HJLed91mZkrcezeb1cPNIF2lOPDkWiNMMUtPKXzlDxZUIW9oGY=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCjXBsDK5cvECIFhAoz29IGw',
#       'authorChannelId': {'value': 'UCjXBsDK5cvECIFhAoz29IGw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-03T02:37:23Z',
#       'updatedAt': '2023-07-03T02:37:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '7c2ZwWfQ44X5fmc3V9m3TC0azeo',
#    'id': 'Ugz7TZprp1xB4c3qdWV4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'lf8GR4VyHhfKkkdgCdgSZ1-8GxA',
#      'id': 'Ugz7TZprp1xB4c3qdWV4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'I love the indian beats.',
#       'textOriginal': 'I love the indian beats.',
#       'authorDisplayName': 'Ralph Peter Bilbao',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AOPolaRU5NAAzDWdyV9nCuMZmpmuLrK2Ab5eDckqVPOQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCbMuT9whs0g4X8vUOHlja2Q',
#       'authorChannelId': {'value': 'UCbMuT9whs0g4X8vUOHlja2Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-03T00:25:11Z',
#       'updatedAt': '2023-07-03T00:25:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'RmLDfheLMcOO5c7THoSDlemAkYo',
#    'id': 'Ugzv0nZffbzdA2j6YH54AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'c8kgmJ6b22pmJz5eyW5acO0JYdk',
#      'id': 'Ugzv0nZffbzdA2j6YH54AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'Been a while since I have mixed..but what kind of board is she using? Anyone? I see a delay but no x cross fader.',
#       'textOriginal': 'Been a while since I have mixed..but what kind of board is she using? Anyone? I see a delay but no x cross fader.',
#       'authorDisplayName': 'Gregory Stiller',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AGIKgqMHbiQ7BAVbkuh_Sxh3rcx7idXVEhpHgsZZu4dC=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCPsw98vmAaA9mhdGHyrr7ZA',
#       'authorChannelId': {'value': 'UCPsw98vmAaA9mhdGHyrr7ZA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-02T21:59:30Z',
#       'updatedAt': '2023-07-02T21:59:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'UT0WXRiZHkaJYzgOFF-VM2sRpq8',
#    'id': 'Ugw9MZQwYkESJ35owbZ4AaABAg',
#    'snippet': {'videoId': 'Beld090NIoo',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'YOwYHa1G04qkEYl1xK9n_1-jqWM',
#      'id': 'Ugw9MZQwYkESJ35owbZ4AaABAg',
#      'snippet': {'videoId': 'Beld090NIoo',
#       'textDisplay': 'very unique music! great unexpected mix &lt;3',
#       'textOriginal': 'very unique music! great unexpected mix <3',
#       'authorDisplayName': 'Betty Bet',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AOPolaSzAt3GfA65IBNaDplurVOCTnEHi8g-rsOI4KKr598=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCHktwWVNDGdTkGvRBlYzaew',
#       'authorChannelId': {'value': 'UCHktwWVNDGdTkGvRBlYzaew'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-07-02T20:51:35Z',
#       'updatedAt': '2023-07-02T20:51:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
request = youtube.commentThreads().list(part='snippet,replies',videoId=video_id)

# %%
response = request.execute()

# %%
# extracting required info
# from each result object
comments = []
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
    comments.append(comment)

# %%
comments
# Out:
# ['thats really great !!!!',
#  'Great mix thank you',
#  'Fire 🔥 in da house!! Dem a murdera!!!!',
#  'Esto es espectacular! muy muy bueno',
#  'почему только сейчас мне попались ваши великолепные сэты.....спасибо)',
#  'indian vibes',
#  'Loving the plants and the set up',
#  'good music and very bad dijing skills (shame)',
#  'what an incredible set...thank you for introducing me to the dub specialist!!',
#  'Yeeeees ❤',
#  '🎉 super!',
#  'Anyone have any recommendations of other dj’s or music similar to this? I am in love with this mix such  a good vibe! Thanks ahead of time appreciate you 🙃❤️🎶🍄',
#  'The last five minutes got me hypedfruitlooped! LOVED THIS SET MAAAN!',
#  'This perked me up so much today at work!',
#  '<a href="https://www.youtube.com/watch?v=Beld090NIoo&amp;t=28m30s">28:30</a> OMFG THIS TRACK',
#  'what&#39;s that rotary mixer? can&#39;t quite read the name without my glasses..',
#  'Thank you. This was perfect for my night of relaxation.',
#  'I love the indian beats.',
#  'Been a while since I have mixed..but what kind of board is she using? Anyone? I see a delay but no x cross fader.',
#  'very unique music! great unexpected mix &lt;3']

# %%
new_request = youtube.commentThreads().list_next(previous_request=request, previous_response=response)

# %%
new_response = new_request.execute()

# %%
comments = []
for item in new_response['items']:
    comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
    comments.append(comment)

# %%
comments
# Out:
# ['Watching from London UK.❤',
#  'Easy Dread! 🙏',
#  'This is some good stuff. Thank you.  We were given some old vinyls and. We d like to put something together. Wehere do we start. What kind of mixers unguys recomemd, thank you.<br>We have a lil back ground in guitar playing loopers, delays etc but never have use mixers<br>, some guidance will be appreciated. Thank you.',
#  'Oh yes this is is good. Really good.',
#  'I love it! Is there Renaud Garcia-Fons in second or third track? Cool',
#  '👍',
#  'I remember buying the Armagideon album from the band themselves over 30 years ago.  Great to see it in this fantastic set.',
#  'Beautiful journey💛',
#  'Supa groovy, really...this is sweeeet! Love it!',
#  'Love the melodies of middle eastern, beautiful.',
#  'I don&#39;t like it when they touch the knobs like a safecracker for no reason.',
#  'thanks',
#  'F     U    N    K    Y   !!',
#  'de novo!',
#  'Percussive Dub, Spiritual Jazz &amp; Psychedelic Grooves is really not what floats my boat but I like the setup and production. Cheers. 🙂',
#  'Nice rotary mixer!',
#  'YUSSSSS!!!    Good vibes, good sounds, fabulous plants……….EXCEPT all those damn commercials fcking it all up. <br><br>I subscribed then unsubscribed half way through this set.',
#  '<a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a><a href="about:invalid#zCSafez"></a>',
#  'plants look healthy',
#  'Dub has a certain feeling to it, a feeling that feels good.']

# %% [markdown]
# ### temporarily save the data

# %%
import pandas as pd
df = pd.DataFrame(data={'video_id': [video_id for _ in comments],
                        'comments': comments})
df
# Out:
#        video_id                                           comments
# 0   -Q09nP62VnU  It is a pity that you have such a sick way of ...
# 1   -Q09nP62VnU                        Berlin forever needs Tresor
# 2   -Q09nP62VnU  Dimitri is a real boss, all love and respect f...
# 3   -Q09nP62VnU  THX Dimitri for the amazing and very intensive...
# 4   -Q09nP62VnU  Names and relevance of those interviewed? Seem...
# 5   -Q09nP62VnU                     Sogeil,danke für den Beitrag!!
# 6   -Q09nP62VnU  Clubs Like Omen, Tresor, Legoa Menen are legen...
# 7   -Q09nP62VnU  If you go to the legendary place, you know who...
# 8   -Q09nP62VnU                                              😭😭😭😭😭
# 9   -Q09nP62VnU                                                🖤🙌🖤
# 10  -Q09nP62VnU  This city and tthe techno world owes so much t...
# 11  -Q09nP62VnU  track ID <a href="https://www.youtube.com/watc...
# 12  -Q09nP62VnU                   need more video about this topic
# 13  -Q09nP62VnU  FYI: it is presented as if the new tresor is i...
# 14  -Q09nP62VnU                                       Boring AF =/
# 15  -Q09nP62VnU  Lovely, but Resident Advisor fails to give the...
# 16  -Q09nP62VnU  btw small typo in the music credits, Joey Balt...
# 17  -Q09nP62VnU  Had one of the best nights of my life at Treso...
# 18  -Q09nP62VnU  It sucks that pretty much the only thing Berli...
# 19  -Q09nP62VnU  That&#39;s a great story RA, albeit one told m...

# %%
df.to_csv('sample_data.csv',index=False)
